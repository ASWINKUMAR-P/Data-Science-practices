# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
ds=pd.DataFrame(np.random.rand(10,4),index=pd.date_range('1/1/2000',periods=10),columns=list('ABCD'))

# %%
ds
# Out:
#                    A         B         C         D
# 2000-01-01  0.652084  0.622123  0.702764  0.767013
# 2000-01-02  0.764563  0.587724  0.646003  0.936267
# 2000-01-03  0.989349  0.399352  0.150592  0.905795
# 2000-01-04  0.658592  0.600166  0.470189  0.939315
# 2000-01-05  0.367882  0.279296  0.015525  0.210899
# 2000-01-06  0.382871  0.484524  0.187878  0.672122
# 2000-01-07  0.018234  0.396647  0.878550  0.122891
# 2000-01-08  0.518539  0.442189  0.841043  0.053544
# 2000-01-09  0.830890  0.068783  0.437370  0.110020
# 2000-01-10  0.586772  0.705527  0.083552  0.953149

# %%
ds.plot()
# Out:
# <AxesSubplot:>

# %%
ds.plot.bar()
# Out:
# <AxesSubplot:>

# %%
ds1=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])

# %%
ds1.plot.bar()
# Out:
# <AxesSubplot:>

# %%
ds1 = pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])

# %%
ds1.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
ds1 = pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
ds1.plot.barh(stacked=True)
# Out:
# <AxesSubplot:>

# %%
ds = pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
ds.plot.box()
# Out:
# <AxesSubplot:>

# %%
ds = pd.DataFrame(np.random.rand(10,6),columns=['A','B','C','D','E','F'])
ds.plot.box()
# Out:
# <AxesSubplot:>

# %%
ds = pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
ds.plot.area()
# Out:
# <AxesSubplot:>

# %%
ds = pd.DataFrame(np.random.rand(40,4),columns=['A','B','C','D'])
ds.plot.scatter(x='A',y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
ds = pd.DataFrame('C:\Users\aswin\Downloads\archive\president_heights.csv')
# Out:
#   File "C:\Users\aswin\AppData\Local\Temp\ipykernel_23032\3932729414.py", line 1
#     ds = pd.DataFrame('C:\Users\aswin\Downloads\archive\president_heights.csv')
#                                                                               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
ds = pd.DataFrame(r'C:\Users\aswin\Downloads\archive\president_heights.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23032\2267233066.py in <module>
# ----> 1 ds = pd.DataFrame(r'C:\Users\aswin\Downloads\archive\president_heights.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     754         else:
#     755             if index is None or columns is None:
# --> 756                 raise ValueError("DataFrame constructor not properly called!")
#     757
#     758             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
ds = pd.DataFrame('C:\\Users\\aswin\\Downloads\\archive\\president_heights.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23032\4250020112.py in <module>
# ----> 1 ds = pd.DataFrame('C:\\Users\\aswin\\Downloads\\archive\\president_heights.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     754         else:
#     755             if index is None or columns is None:
# --> 756                 raise ValueError("DataFrame constructor not properly called!")
#     757
#     758             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
ds = pd.read_csv('C:\\Users\\aswin\\Downloads\\archive\\president_heights.csv')

# %%
ds
# Out:
#     order                    name  height(cm)
# 0       1       George Washington         189
# 1       2              John Adams         170
# 2       3        Thomas Jefferson         189
# 3       4           James Madison         163
# 4       5            James Monroe         183
# 5       6       John Quincy Adams         171
# 6       7          Andrew Jackson         185
# 7       8        Martin Van Buren         168
# 8       9  William Henry Harrison         173
# 9      10              John Tyler         183
# 10     11           James K. Polk         173
# 11     12          Zachary Taylor         173
# 12     13        Millard Fillmore         175
# 13     14         Franklin Pierce         178
# 14     15          James Buchanan         183
# 15     16         Abraham Lincoln         193
# 16     17          Andrew Johnson         178
# 17     18        Ulysses S. Grant         173
# 18     19     Rutherford B. Hayes         174
# ...

# %%
import numpy as np
import pandas as pd

# %%
data = [1,2,3,4,5]
data
# Out:
# [1, 2, 3, 4, 5]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
df[0][2]
# Out:
# 3

# %%
data1 = ['Arun',94],['Aswin',19],['Bharath',100],['Hemanth',22],['Charan',0]

# %%
df1= pd.DataFrame(data1)

# %%
df1
# Out:
#          0    1
# 0     Arun   94
# 1    Aswin   19
# 2  Bharath  100
# 3  Hemanth   22
# 4   Charan    0

# %%
df1.iloc[2]
# Out:
# 0    Bharath
# 1        100
# Name: 2, dtype: object

# %%
df1.iloc[2]
# Out:
# 0    Bharath
# 1        100
# Name: 2, dtype: object

# %%
df1[0:][2:3]
# Out:
#          0    1
# 2  Bharath  100

# %%
data = ['Arun',94],['Aswin',19],['Bharath',100],['Hemanth',22],['Charan',0]
df= pd.DataFrame(data1,columns=['Name','Age'])

# %%
df
# Out:
#       Name  Age
# 0     Arun   94
# 1    Aswin   19
# 2  Bharath  100
# 3  Hemanth   22
# 4   Charan    0

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='Name',y='Age')
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Age'>

# %%
data2 = {
    'Name':['Aswin','Bharath','Chirudeep','Binlet','Hemanth','Charan'],
    'Age':[19,20,100,1500,0,50],
    'Department':['CSE','IT','CSBS','CSE','ECE','CSE']
        }
df=pd.DataFrame(data2,columns=['Name','Age','Department'],index=['First','Second','Third','Forth','Fifth','Sixth'])

# %%
df
# Out:
#              Name   Age Department
# First       Aswin    19        CSE
# Second    Bharath    20         IT
# Third   Chirudeep   100       CSBS
# Forth      Binlet  1500        CSE
# Fifth     Hemanth     0        ECE
# Sixth      Charan    50        CSE

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>
